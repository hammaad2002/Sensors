# %% [markdown]
# # **Pictures:**
#
# 1)
# ![alt text](image.png)
#
# 2)
# ![image.png](attachment:image.png)
#
# 3)
# ![image-2.png](attachment:image-2.png)
#
# 4) Pinhole vs Lens based camera:
#
# ![image-3.png](attachment:image-3.png)
#
# Another one:
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Camera distortion:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Focal point is the point which we call aperature and basically it is the point where rays cross each other.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
'''
FOV calculation:
            
           /|
          / |
         /  |  (This flat plane is basically the image plane or where
        /   |  the chip of camera is present that basically quantizes
       /    |  the rays of light to fixed number of pixels.)
      /     |   
     /      |  height / 2
    /       |   
   /        |
  /         |
 / theta/ 2 |
/-----------|
    focal
    length

           perpendular
tangent =  -----------
              base

                 height / 2
tan(theta/2) =  ------------
                focal length

               height 
tan(theta/2) = ------ ÷ focal length
                 2

               height        1
tan(theta/2) = ------ x ------------
                 2      focal length


                    height
tan(theta/2) = ----------------
               2 * focal length


                      height 
theta/2 = tan-1 (----------------)
                 2 * focal length


                               height
theta or FOV = 2 * tan-1 (----------------)   or 2 * arctan((height) / (2 * focal length))
                          2 * focal length
'''
